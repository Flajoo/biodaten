# %% [markdown]
# # Seminar 4: Gute Hardware für gute Studenten?

# %%
pwd
# Out:
# /home/mflachow/notebooks

# %%
git config --global user.name 'Flajoo'

# %%
git config --global user.email 'jordan-24@web.de'

# %%
git clone https://github.com/Flajoo/biodaten.git
# Out:
# Schwerwiegend: Zielpfad 'biodaten' existiert bereits und ist kein leeres Verzeichnis.
# : 128

# %%
git clone https://github.com/Flajoo/biodaten.git
# Out:
# Klone nach 'biodaten'...
# Warnung: Sie scheinen ein leeres Repository geklont zu haben.

# %% [markdown]
# Es wurde ein leeres Repository aus Git Hub geklont

# %%
pwd
# Out:
# /home/mflachow/notebooks

# %% [markdown]
# Token für GitHub: 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

# %%
ls
# Out:
# biodaten	Biodaten.zip  __MACOSX	      Seminar2.ipynb  Seminar4.ipynb
# biodaten_lokal	image	      Seminar1.ipynb  Seminar3.ipynb

# %%
cd ./biodaten/

# %%
pwd
# Out:
# /home/mflachow/notebooks/biodaten

# %%
ls -lha
# Out:
# insgesamt 4,0K
# drwxr-xr-x 1 mflachow grp-mflachow   8  4. Nov 14:29 .
# drwx------ 1 mflachow grp-mflachow 242  4. Nov 14:52 ..
# drwxr-xr-x 1 mflachow grp-mflachow  98  4. Nov 14:29 .git

# %%
pwd
# Out:
# /home/mflachow/notebooks/biodaten

# %%
ls -lh
# Out:
# insgesamt 8,0K
# -rw-r--r-- 1 mflachow grp-mflachow 4,7K  4. Nov 14:56 Seminar4.ipynb

# %%
touch test.txt

# %% [markdown]
# Touch Befehl um eine Datei zu erstellen

# %%
pwd
# Out:
# /home/mflachow/notebooks/biodaten

# %%
cd ..

# %%
pwd
# Out:
# /home/mflachow/notebooks

# %%
mv tester.txt ./biodaten/
# Out:
# mv: der Aufruf von stat für 'tester.txt' ist nicht möglich: Datei oder Verzeichnis nicht gefunden
# : 1

# %%
touch tester.txt ./biodaten/

# %%
pwd
# Out:
# /home/mflachow/notebooks

# %%
mv tester.txt ./biodaten/

# %%
mv ~/notebooks/biodaten/tester.txt ~/notebooks

# %% [markdown]
# Aufbau des Befehls: mv; was mit Pfadangabe; wohin

# %%
pwd
# Out:
# /home/mflachow/notebooks

# %%
cd ./biodaten/

# %%
pwd
# Out:
# /home/mflachow/notebooks/biodaten

# %%
git add test.txt

# %%
git commit -m 'Moin Meister2'
# Out:
# [main (Root-Commit) 9fabf9c] Moin Meister
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 test.txt

# %% [markdown]
# immer erst add, dann commit -m und zum schluß push, alles in der Kommandozeile.

# %% [markdown]
# Mit git Pull kann man sich in Git Hub aktualisierte Dateien ziehen.

# %%
git add Seminar4.ipynb
